# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
taxi_df=sns.load_dataset('taxis')
taxi_df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
sns.barplot(x='payment',y='total',data=taxi_df,color='red',estimator='std')
plt.show()
plt.tight_layout()

# %%
sns.histplot(x=taxi_df['fare'],color='orange')
plt.show()

# %%
sns.histplot(x=taxi_df['fare'],palette=['y','r'],hue=taxi_df['payment'])
plt.show()

# %%
sns.distplot(x=taxi['fare'],hist=True,kde=False)
plt.show()

# %%
sns.distplot(x=taxi['fare'],hist=False,kde=True)
plt.show()

# %%
sns.distplot(x=taxi['fare'],hist=True,kde=True)
plt.show()

# %%
sns.boxplot(x=taxi_df['fare'],color='purple')
plt.show()

# %%
iris_data=sns.load_dataset('iris')
iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.boxplot(x=iris_data['petal_length'],color='green')
plt.show()

# %%
lower_bound=q1-1.5iqr
upper_bound q3+1.5iqr
iqr=q3-q1

# %%
sns.scatterplot(x=df['fare'],y=df['total'],p
